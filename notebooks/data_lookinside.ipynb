# %%
import pandas as pd

# %%
meta_df = pd.read_json('../res/song_meta.json', typ='frame')

# %%
artists = [len(art_list) for art_list in meta_df['artist_id_basket'].values] 
genres = [len(g_list) for g_list in meta_df['song_gn_gnr_basket'].values]

# %%
meta_df['artist_cnt'] = artists
meta_df['genre_cnt'] = genres

# %%
meta_df[meta_df['artist_cnt'] > 3][:10]
# Out:
#         song_gn_dtl_gnr_basket  issue_date  \
# 103                   [GN1701]    19991231
# 245   [GN1301, GN1308, GN1302]    20180720
# 260   [GN0702, GN0708, GN0701]    20140819
# 296                   [GN0401]    20191005
# 688                   [GN1701]    20171129
# 1261                  [GN1701]    20171225
# 1287          [GN1601, GN1606]    20130409
# 1327  [GN1601, GN1615, GN1610]    20130618
# 1471          [GN0303, GN0301]    20180528
# 1520          [GN1601, GN1605]    20080428
#
#                                              album_name  album_id  \
# 103                                  Dr. Cyclops` Dream   4702483
# 245                                  Head In The Clouds  10174033
# 260                                       트로트 스쿨 Part.1   2275423
# 296                              JTBC 비긴어게인3 Episode 11  10335378
# 688   재즈로 듣는 불멸의 팝송 Best Pops In Urban Jazz (추억의 708...  10115157
# 1261   AL COHN - FOREVER JAZZ HITS VOL.2 (알 콘 재즈 히트 모음)  10131788
# ...

# %%
meta_df[meta_df['genre_cnt'] > 1]
# Out:
#                                    song_gn_dtl_gnr_basket  issue_date  \
# 14                       [GN2704, GN1104, GN1103, GN1101]    20140728
# 17               [GN2503, GN0205, GN2501, GN2506, GN0201]    20160226
# 19               [GN0805, GN0501, GN0502, GN0801, GN0509]    20150205
# 30      [GN2502, GN0205, GN2501, GN2506, GN1501, GN020...    20190519
# 35               [GN0805, GN0501, GN0502, GN0801, GN0509]    20120629
# ...                                                   ...         ...
# 707947                   [GN2704, GN1104, GN1103, GN1101]    20140915
# 707950           [GN2502, GN0205, GN2501, GN2506, GN0201]    20150409
# 707956           [GN2502, GN0204, GN2501, GN2506, GN0201]    20020329
# 707964                   [GN2704, GN1104, GN1103, GN1101]    20131008
# 707981                   [GN2207, GN1501, GN1506, GN1509]    20160601
#
#                               album_name  album_id  artist_id_basket  \
# ...

# %%
a = "AB123"

# %%
a[:-1]+"1"
# Out:
# 'AB121'
